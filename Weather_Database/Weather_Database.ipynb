# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country" : city_country,
                          "Weather Description": city_weather_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | karratha
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | exeter
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | ilulissat
# Processing Record 6 of Set 1 | qui nhon
# Processing Record 7 of Set 1 | dingle
# Processing Record 8 of Set 1 | vuktyl
# Processing Record 9 of Set 1 | north bend
# Processing Record 10 of Set 1 | chokurdakh
# Processing Record 11 of Set 1 | richard toll
# City not found. Skipping...
# Processing Record 12 of Set 1 | xichang
# Processing Record 13 of Set 1 | constitucion
# Processing Record 14 of Set 1 | nadym
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | sayyan
# Processing Record 18 of Set 1 | tautira
# Processing Record 19 of Set 1 | vanimo
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | killybegs
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | prado
# Processing Record 28 of Set 1 | bitkine
# Processing Record 29 of Set 1 | padilla
# Processing Record 30 of Set 1 | seinajoki
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | qasigiannguit
# Processing Record 33 of Set 1 | wajid
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | provideniya
# Processing Record 36 of Set 1 | arraial do cabo
# Processing Record 37 of Set 1 | yangjiang
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | souillac
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | georgiyevskoye
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | yar-sale
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | lompoc
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | avarua
# Processing Record 48 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 1 | klaksvik
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | brazzaville
# Processing Record 2 of Set 2 | asti
# Processing Record 3 of Set 2 | tateyama
# Processing Record 4 of Set 2 | dudinka
# Processing Record 5 of Set 2 | san patricio
# Processing Record 6 of Set 2 | baculin
# Processing Record 7 of Set 2 | tatawin
# Processing Record 8 of Set 2 | khatanga
# Processing Record 9 of Set 2 | esperance
# Processing Record 10 of Set 2 | codrington
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 2 | birjand
# Processing Record 14 of Set 2 | walvis bay
# Processing Record 15 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | kloulklubed
# Processing Record 17 of Set 2 | katangli
# Processing Record 18 of Set 2 | lorengau
# Processing Record 19 of Set 2 | kaitangata
# Processing Record 20 of Set 2 | severo-kurilsk
# Processing Record 21 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 22 of Set 2 | nanyuki
# Processing Record 23 of Set 2 | beatrice
# Processing Record 24 of Set 2 | iranshahr
# Processing Record 25 of Set 2 | thurso
# Processing Record 26 of Set 2 | aksay
# Processing Record 27 of Set 2 | nianzishan
# Processing Record 28 of Set 2 | saint george
# Processing Record 29 of Set 2 | quatre cocos
# Processing Record 30 of Set 2 | mar del plata
# Processing Record 31 of Set 2 | necochea
# Processing Record 32 of Set 2 | salalah
# Processing Record 33 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 34 of Set 2 | pauini
# Processing Record 35 of Set 2 | mpika
# Processing Record 36 of Set 2 | padang
# Processing Record 37 of Set 2 | victoria
# Processing Record 38 of Set 2 | upernavik
# Processing Record 39 of Set 2 | morgan city
# Processing Record 40 of Set 2 | clyde river
# Processing Record 41 of Set 2 | ayan
# Processing Record 42 of Set 2 | grindavik
# Processing Record 43 of Set 2 | kushmurun
# Processing Record 44 of Set 2 | yellowknife
# Processing Record 45 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | vaini
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | jalu
# Processing Record 50 of Set 2 | nizhniy baskunchak
# Processing Record 1 of Set 3 | cherskiy
# Processing Record 2 of Set 3 | batsfjord
# Processing Record 3 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 3 | cape town
# Processing Record 5 of Set 3 | saldanha
# Processing Record 6 of Set 3 | nikolskoye
# Processing Record 7 of Set 3 | seminole
# Processing Record 8 of Set 3 | salta
# Processing Record 9 of Set 3 | tuatapere
# Processing Record 10 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 3 | monroe
# Processing Record 12 of Set 3 | liwale
# Processing Record 13 of Set 3 | bambous virieux
# Processing Record 14 of Set 3 | tiksi
# Processing Record 15 of Set 3 | shingu
# Processing Record 16 of Set 3 | laguna
# Processing Record 17 of Set 3 | pacatuba
# Processing Record 18 of Set 3 | sao joao da barra
# Processing Record 19 of Set 3 | norman wells
# Processing Record 20 of Set 3 | san marcos
# Processing Record 21 of Set 3 | sorland
# Processing Record 22 of Set 3 | port alfred
# Processing Record 23 of Set 3 | narsaq
# Processing Record 24 of Set 3 | chuy
# Processing Record 25 of Set 3 | moranbah
# Processing Record 26 of Set 3 | atuona
# Processing Record 27 of Set 3 | guerrero negro
# Processing Record 28 of Set 3 | hermanus
# Processing Record 29 of Set 3 | puerto rico
# Processing Record 30 of Set 3 | langfang
# Processing Record 31 of Set 3 | muisne
# Processing Record 32 of Set 3 | rawson
# Processing Record 33 of Set 3 | general delgado
# Processing Record 34 of Set 3 | parakan
# Processing Record 35 of Set 3 | talnakh
# Processing Record 36 of Set 3 | mamallapuram
# Processing Record 37 of Set 3 | cabo san lucas
# Processing Record 38 of Set 3 | te anau
# Processing Record 39 of Set 3 | swellendam
# Processing Record 40 of Set 3 | butaritari
# Processing Record 41 of Set 3 | port lincoln
# Processing Record 42 of Set 3 | shenandoah
# Processing Record 43 of Set 3 | naze
# Processing Record 44 of Set 3 | camana
# Processing Record 45 of Set 3 | kapuskasing
# Processing Record 46 of Set 3 | pevek
# Processing Record 47 of Set 3 | puro
# Processing Record 48 of Set 3 | sa kaeo
# Processing Record 49 of Set 3 | vila velha
# Processing Record 50 of Set 3 | puerto baquerizo moreno
# Processing Record 1 of Set 4 | longyearbyen
# Processing Record 2 of Set 4 | mehamn
# Processing Record 3 of Set 4 | thompson
# Processing Record 4 of Set 4 | qaanaaq
# Processing Record 5 of Set 4 | meulaboh
# Processing Record 6 of Set 4 | maceio
# Processing Record 7 of Set 4 | mangrol
# Processing Record 8 of Set 4 | vila franca do campo
# Processing Record 9 of Set 4 | clarence town
# Processing Record 10 of Set 4 | bethel
# Processing Record 11 of Set 4 | huatusco
# Processing Record 12 of Set 4 | saskylakh
# Processing Record 13 of Set 4 | chibombo
# Processing Record 14 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 4 | puerto leguizamo
# Processing Record 16 of Set 4 | matay
# Processing Record 17 of Set 4 | portales
# Processing Record 18 of Set 4 | oranjemund
# Processing Record 19 of Set 4 | san cristobal
# Processing Record 20 of Set 4 | kibre mengist
# Processing Record 21 of Set 4 | kerewan
# Processing Record 22 of Set 4 | nyazepetrovsk
# Processing Record 23 of Set 4 | townsville
# Processing Record 24 of Set 4 | cidreira
# Processing Record 25 of Set 4 | zhucheng
# Processing Record 26 of Set 4 | kavieng
# Processing Record 27 of Set 4 | manggar
# Processing Record 28 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 4 | chioggia
# Processing Record 30 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 4 | airai
# Processing Record 32 of Set 4 | labuhan
# Processing Record 33 of Set 4 | koslan
# Processing Record 34 of Set 4 | burnie
# Processing Record 35 of Set 4 | hithadhoo
# Processing Record 36 of Set 4 | lavrentiya
# Processing Record 37 of Set 4 | tokur
# Processing Record 38 of Set 4 | talcahuano
# Processing Record 39 of Set 4 | jhalrapatan
# Processing Record 40 of Set 4 | aichach
# Processing Record 41 of Set 4 | ahar
# Processing Record 42 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 4 | aklavik
# Processing Record 44 of Set 4 | horodnytsya
# Processing Record 45 of Set 4 | sambava
# Processing Record 46 of Set 4 | alampur
# Processing Record 47 of Set 4 | kumukh
# Processing Record 48 of Set 4 | adrar
# Processing Record 49 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 4 | cockburn town
# Processing Record 1 of Set 5 | manitouwadge
# Processing Record 2 of Set 5 | kamenka
# Processing Record 3 of Set 5 | yulara
# Processing Record 4 of Set 5 | fortuna
# Processing Record 5 of Set 5 | komsomolskiy
# Processing Record 6 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 5 | yerbogachen
# Processing Record 8 of Set 5 | sioux lookout
# Processing Record 9 of Set 5 | odesskoye
# Processing Record 10 of Set 5 | camacupa
# Processing Record 11 of Set 5 | henties bay
# Processing Record 12 of Set 5 | jagalur
# Processing Record 13 of Set 5 | hollins
# Processing Record 14 of Set 5 | mitsamiouli
# Processing Record 15 of Set 5 | kodiak
# Processing Record 16 of Set 5 | saint-philippe
# Processing Record 17 of Set 5 | sapulpa
# Processing Record 18 of Set 5 | bukachacha
# Processing Record 19 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 5 | najran
# Processing Record 21 of Set 5 | kirksville
# Processing Record 22 of Set 5 | saint-georges
# Processing Record 23 of Set 5 | perth
# Processing Record 24 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 5 | bengkulu
# Processing Record 26 of Set 5 | matviyivka
# Processing Record 27 of Set 5 | makung
# City not found. Skipping...
# Processing Record 28 of Set 5 | biaora
# Processing Record 29 of Set 5 | okato
# Processing Record 30 of Set 5 | torbay
# Processing Record 31 of Set 5 | faanui
# Processing Record 32 of Set 5 | lagoa
# Processing Record 33 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 34 of Set 5 | pisco
# Processing Record 35 of Set 5 | sola
# Processing Record 36 of Set 5 | kruisfontein
# Processing Record 37 of Set 5 | moose factory
# Processing Record 38 of Set 5 | georgetown
# Processing Record 39 of Set 5 | sakakah
# Processing Record 40 of Set 5 | bathsheba
# Processing Record 41 of Set 5 | kidal
# Processing Record 42 of Set 5 | isangel
# Processing Record 43 of Set 5 | bandarbeyla
# Processing Record 44 of Set 5 | hambantota
# Processing Record 45 of Set 5 | teguise
# Processing Record 46 of Set 5 | cayenne
# Processing Record 47 of Set 5 | sheridan
# Processing Record 48 of Set 5 | coquimbo
# Processing Record 49 of Set 5 | monte cristi
# City not found. Skipping...
# Processing Record 50 of Set 5 | luderitz
# Processing Record 1 of Set 6 | lazurne
# Processing Record 2 of Set 6 | port-gentil
# Processing Record 3 of Set 6 | goderich
# Processing Record 4 of Set 6 | qaqortoq
# Processing Record 5 of Set 6 | dikson
# Processing Record 6 of Set 6 | manzil tamim
# City not found. Skipping...
# Processing Record 7 of Set 6 | saint anthony
# Processing Record 8 of Set 6 | tilichiki
# Processing Record 9 of Set 6 | ribeira grande
# Processing Record 10 of Set 6 | khonsa
# Processing Record 11 of Set 6 | qandala
# Processing Record 12 of Set 6 | ust-kuyga
# Processing Record 13 of Set 6 | marsh harbour
# Processing Record 14 of Set 6 | hofn
# Processing Record 15 of Set 6 | sao filipe
# Processing Record 16 of Set 6 | ugoofaaru
# Processing Record 17 of Set 6 | sturgis
# Processing Record 18 of Set 6 | mahebourg
# Processing Record 19 of Set 6 | hervey bay
# Processing Record 20 of Set 6 | ossora
# Processing Record 21 of Set 6 | vallenar
# Processing Record 22 of Set 6 | ngong
# Processing Record 23 of Set 6 | puerto colombia
# Processing Record 24 of Set 6 | tuy hoa
# Processing Record 25 of Set 6 | lebu
# Processing Record 26 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 6 | halifax
# Processing Record 28 of Set 6 | wlodawa
# Processing Record 29 of Set 6 | el balyana
# City not found. Skipping...
# Processing Record 30 of Set 6 | amot
# Processing Record 31 of Set 6 | auki
# Processing Record 32 of Set 6 | vardo
# Processing Record 33 of Set 6 | egvekinot
# Processing Record 34 of Set 6 | pochutla
# Processing Record 35 of Set 6 | horizontina
# Processing Record 36 of Set 6 | poum
# Processing Record 37 of Set 6 | yongzhou
# Processing Record 38 of Set 6 | yingzhong
# City not found. Skipping...
# Processing Record 39 of Set 6 | safaga
# Processing Record 40 of Set 6 | villa bruzual
# Processing Record 41 of Set 6 | richards bay
# Processing Record 42 of Set 6 | morant bay
# Processing Record 43 of Set 6 | buala
# Processing Record 44 of Set 6 | hamilton
# Processing Record 45 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 6 | nuuk
# Processing Record 47 of Set 6 | diamantino
# Processing Record 48 of Set 6 | cam pha
# City not found. Skipping...
# Processing Record 49 of Set 6 | gornji milanovac
# Processing Record 50 of Set 6 | port elizabeth
# Processing Record 1 of Set 7 | cantaura
# Processing Record 2 of Set 7 | otavalo
# Processing Record 3 of Set 7 | vanavara
# Processing Record 4 of Set 7 | bartica
# Processing Record 5 of Set 7 | alto paraguai
# Processing Record 6 of Set 7 | mount gambier
# Processing Record 7 of Set 7 | san antonio
# Processing Record 8 of Set 7 | cabedelo
# Processing Record 9 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 7 | igarka
# Processing Record 11 of Set 7 | northam
# Processing Record 12 of Set 7 | lujiang
# Processing Record 13 of Set 7 | tongren
# Processing Record 14 of Set 7 | maarianhamina
# Processing Record 15 of Set 7 | momcilgrad
# City not found. Skipping...
# Processing Record 16 of Set 7 | guhagar
# Processing Record 17 of Set 7 | garm
# City not found. Skipping...
# Processing Record 18 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 7 | sechura
# Processing Record 20 of Set 7 | iki-burul
# Processing Record 21 of Set 7 | banda aceh
# Processing Record 22 of Set 7 | krasnoselkup
# Processing Record 23 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 7 | east london
# Processing Record 25 of Set 7 | salavat
# Processing Record 26 of Set 7 | hobyo
# Processing Record 27 of Set 7 | portland
# Processing Record 28 of Set 7 | saint-leu
# Processing Record 29 of Set 7 | homer
# Processing Record 30 of Set 7 | ayaviri
# Processing Record 31 of Set 7 | yashkul
# Processing Record 32 of Set 7 | avera
# Processing Record 33 of Set 7 | verkhnyaya inta
# Processing Record 34 of Set 7 | broken hill
# Processing Record 35 of Set 7 | vestmannaeyjar
# Processing Record 36 of Set 7 | khilok
# Processing Record 37 of Set 7 | high level
# Processing Record 38 of Set 7 | korem
# Processing Record 39 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 40 of Set 7 | port hardy
# Processing Record 41 of Set 7 | faya
# Processing Record 42 of Set 7 | oranjestad
# Processing Record 43 of Set 7 | nushki
# Processing Record 44 of Set 7 | asau
# Processing Record 45 of Set 7 | nemuro
# Processing Record 46 of Set 7 | kalevala
# Processing Record 47 of Set 7 | lantangan
# Processing Record 48 of Set 7 | los llanos de aridane
# Processing Record 49 of Set 7 | zyryanka
# Processing Record 50 of Set 7 | banepa
# Processing Record 1 of Set 8 | alihe
# Processing Record 2 of Set 8 | kilimatinde
# Processing Record 3 of Set 8 | jaisalmer
# Processing Record 4 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 8 | caravelas
# Processing Record 6 of Set 8 | soyo
# Processing Record 7 of Set 8 | cam ranh
# Processing Record 8 of Set 8 | gao
# Processing Record 9 of Set 8 | fort nelson
# Processing Record 10 of Set 8 | dicabisagan
# Processing Record 11 of Set 8 | tilaran
# Processing Record 12 of Set 8 | palmer
# Processing Record 13 of Set 8 | leh
# Processing Record 14 of Set 8 | gobabis
# Processing Record 15 of Set 8 | garowe
# Processing Record 16 of Set 8 | alpena
# Processing Record 17 of Set 8 | port keats
# Processing Record 18 of Set 8 | williams lake
# Processing Record 19 of Set 8 | poindimie
# Processing Record 20 of Set 8 | yinchuan
# Processing Record 21 of Set 8 | afanasyevo
# City not found. Skipping...
# Processing Record 22 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 8 | mayumba
# Processing Record 24 of Set 8 | casper
# Processing Record 25 of Set 8 | nanortalik
# Processing Record 26 of Set 8 | geraldton
# Processing Record 27 of Set 8 | ketchikan
# Processing Record 28 of Set 8 | cairns
# Processing Record 29 of Set 8 | chake chake
# Processing Record 30 of Set 8 | jaumave
# Processing Record 31 of Set 8 | shimoda
# Processing Record 32 of Set 8 | tagusao
# Processing Record 33 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 8 | lodwar
# Processing Record 35 of Set 8 | ostersund
# Processing Record 36 of Set 8 | portoferraio
# Processing Record 37 of Set 8 | boa vista
# Processing Record 38 of Set 8 | iskateley
# Processing Record 39 of Set 8 | san juan
# Processing Record 40 of Set 8 | karakulino
# Processing Record 41 of Set 8 | kargil
# Processing Record 42 of Set 8 | ouallam
# Processing Record 43 of Set 8 | nicoya
# Processing Record 44 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 8 | fare
# Processing Record 46 of Set 8 | suntar
# Processing Record 47 of Set 8 | tsalka
# Processing Record 48 of Set 8 | kichmengskiy gorodok
# Processing Record 49 of Set 8 | vao
# Processing Record 50 of Set 8 | yamada
# Processing Record 1 of Set 9 | amahai
# Processing Record 2 of Set 9 | kasongo-lunda
# Processing Record 3 of Set 9 | bourail
# Processing Record 4 of Set 9 | san andres
# Processing Record 5 of Set 9 | koutsouras
# Processing Record 6 of Set 9 | shar
# Processing Record 7 of Set 9 | ouadda
# Processing Record 8 of Set 9 | fukue
# Processing Record 9 of Set 9 | zhob
# Processing Record 10 of Set 9 | somerset
# Processing Record 11 of Set 9 | pahalgam
# Processing Record 12 of Set 9 | bodden town
# Processing Record 13 of Set 9 | bara
# Processing Record 14 of Set 9 | dunedin
# Processing Record 15 of Set 9 | yarada
# Processing Record 16 of Set 9 | turbat
# Processing Record 17 of Set 9 | port hedland
# Processing Record 18 of Set 9 | callaway
# Processing Record 19 of Set 9 | tutoia
# Processing Record 20 of Set 9 | along
# Processing Record 21 of Set 9 | sitka
# Processing Record 22 of Set 9 | verkhnevilyuysk
# Processing Record 23 of Set 9 | leningradskiy
# Processing Record 24 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 9 | jizan
# Processing Record 26 of Set 9 | touros
# Processing Record 27 of Set 9 | cantagallo
# Processing Record 28 of Set 9 | alofi
# Processing Record 29 of Set 9 | svetlaya
# Processing Record 30 of Set 9 | general pico
# Processing Record 31 of Set 9 | foldeak
# Processing Record 32 of Set 9 | bolgatanga
# Processing Record 33 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 34 of Set 9 | zapolyarnyy
# Processing Record 35 of Set 9 | izumo
# Processing Record 36 of Set 9 | vitimskiy
# City not found. Skipping...
# Processing Record 37 of Set 9 | atasu
# Processing Record 38 of Set 9 | mehran
# Processing Record 39 of Set 9 | kanniyakumari
# Processing Record 40 of Set 9 | huntsville
# Processing Record 41 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 42 of Set 9 | sumbe
# Processing Record 43 of Set 9 | narrabri
# Processing Record 44 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 45 of Set 9 | sinop
# Processing Record 46 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 47 of Set 9 | saint-augustin
# Processing Record 48 of Set 9 | miquelon
# Processing Record 49 of Set 9 | taltal
# Processing Record 50 of Set 9 | polunochnoye
# Processing Record 1 of Set 10 | santa fe
# Processing Record 2 of Set 10 | gejiu
# Processing Record 3 of Set 10 | warmbad
# Processing Record 4 of Set 10 | lata
# Processing Record 5 of Set 10 | howard springs
# Processing Record 6 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 7 of Set 10 | ponta do sol
# Processing Record 8 of Set 10 | beringovskiy
# Processing Record 9 of Set 10 | port blair
# Processing Record 10 of Set 10 | hit
# Processing Record 11 of Set 10 | ust-tsilma
# Processing Record 12 of Set 10 | nalut
# Processing Record 13 of Set 10 | ipswich
# Processing Record 14 of Set 10 | novokizhinginsk
# Processing Record 15 of Set 10 | antofagasta
# Processing Record 16 of Set 10 | hovd
# Processing Record 17 of Set 10 | gretna
# Processing Record 18 of Set 10 | mandalgovi
# Processing Record 19 of Set 10 | ghatanji
# Processing Record 20 of Set 10 | kalabo
# Processing Record 21 of Set 10 | puerto del rosario
# Processing Record 22 of Set 10 | cervo
# Processing Record 23 of Set 10 | marystown
# Processing Record 24 of Set 10 | itarema
# Processing Record 25 of Set 10 | noyon
# Processing Record 26 of Set 10 | iqaluit
# Processing Record 27 of Set 10 | qinzhou
# Processing Record 28 of Set 10 | namibe
# Processing Record 29 of Set 10 | nichinan
# Processing Record 30 of Set 10 | mago
# Processing Record 31 of Set 10 | guaymas
# Processing Record 32 of Set 10 | culpeper
# Processing Record 33 of Set 10 | comodoro rivadavia
# Processing Record 34 of Set 10 | tigre
# Processing Record 35 of Set 10 | chernyshevskiy
# Processing Record 36 of Set 10 | nouakchott
# Processing Record 37 of Set 10 | takoradi
# Processing Record 38 of Set 10 | novyy redant
# City not found. Skipping...
# Processing Record 39 of Set 10 | swinoujscie
# Processing Record 40 of Set 10 | bitung
# Processing Record 41 of Set 10 | andenes
# Processing Record 42 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 43 of Set 10 | sao sebastiao
# Processing Record 44 of Set 10 | pandhana
# Processing Record 45 of Set 10 | batabano
# Processing Record 46 of Set 10 | bronnoysund
# Processing Record 47 of Set 10 | batticaloa
# Processing Record 48 of Set 10 | elliot
# Processing Record 49 of Set 10 | pandelys
# City not found. Skipping...
# Processing Record 50 of Set 10 | ancud
# Processing Record 1 of Set 11 | visby
# Processing Record 2 of Set 11 | staryy nadym
# Processing Record 3 of Set 11 | anchorage
# Processing Record 4 of Set 11 | bom jesus
# Processing Record 5 of Set 11 | acapulco
# Processing Record 6 of Set 11 | opuwo
# Processing Record 7 of Set 11 | abu zabad
# Processing Record 8 of Set 11 | teyateyaneng
# Processing Record 9 of Set 11 | lashio
# Processing Record 10 of Set 11 | canberra
# Processing Record 11 of Set 11 | srednekolymsk
# Processing Record 12 of Set 11 | xuddur
# Processing Record 13 of Set 11 | matara
# Processing Record 14 of Set 11 | sovetskoye
# Processing Record 15 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 16 of Set 11 | hasaki
# Processing Record 17 of Set 11 | rust
# Processing Record 18 of Set 11 | pascoag
# Processing Record 19 of Set 11 | harbour breton
# Processing Record 20 of Set 11 | ismailia
# Processing Record 21 of Set 11 | balikpapan
# Processing Record 22 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 11 | naantali
# Processing Record 24 of Set 11 | impfondo
# Processing Record 25 of Set 11 | funehiki
# Processing Record 26 of Set 11 | lamu
# Processing Record 27 of Set 11 | gilgit
# Processing Record 28 of Set 11 | westport
# Processing Record 29 of Set 11 | am timan
# Processing Record 30 of Set 11 | crotone
# Processing Record 31 of Set 11 | rosarito
# Processing Record 32 of Set 11 | banikoara
# Processing Record 33 of Set 11 | chapais
# Processing Record 34 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 11 | dhidhdhoo
# Processing Record 36 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 11 | novyy urengoy
# Processing Record 38 of Set 11 | havoysund
# Processing Record 39 of Set 11 | hurghada
# Processing Record 40 of Set 11 | assis
# Processing Record 41 of Set 11 | dawei
# Processing Record 42 of Set 11 | tommot
# Processing Record 43 of Set 11 | clovis
# Processing Record 44 of Set 11 | mollendo
# Processing Record 45 of Set 11 | nizhniy kuranakh
# Processing Record 46 of Set 11 | vreed en hoop
# City not found. Skipping...
# Processing Record 47 of Set 11 | imbituba
# Processing Record 48 of Set 11 | mumford
# Processing Record 49 of Set 11 | krasnogorsk
# Processing Record 50 of Set 11 | gaziantep
# Processing Record 1 of Set 12 | yining
# Processing Record 2 of Set 12 | wangaratta
# Processing Record 3 of Set 12 | tuskegee
# Processing Record 4 of Set 12 | vaovai
# City not found. Skipping...
# Processing Record 5 of Set 12 | pousat
# City not found. Skipping...
# Processing Record 6 of Set 12 | troy
# Processing Record 7 of Set 12 | medea
# Processing Record 8 of Set 12 | shobara
# Processing Record 9 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 10 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 12 | chikwawa
# Processing Record 12 of Set 12 | sarakhs
# Processing Record 13 of Set 12 | genhe
# Processing Record 14 of Set 12 | ravar
# Processing Record 15 of Set 12 | ibara
# Processing Record 16 of Set 12 | pyay
# Processing Record 17 of Set 12 | ambulu
# Processing Record 18 of Set 12 | phayuha khiri
# Processing Record 19 of Set 12 | salekhard
# Processing Record 20 of Set 12 | khorixas
# Processing Record 21 of Set 12 | teknaf
# Processing Record 22 of Set 12 | grand-santi
# Processing Record 23 of Set 12 | neuquen
# Processing Record 24 of Set 12 | springdale
# Processing Record 25 of Set 12 | mlowo
# Processing Record 26 of Set 12 | pacific grove
# Processing Record 27 of Set 12 | russell
# Processing Record 28 of Set 12 | zhangye
# Processing Record 29 of Set 12 | deputatskiy
# Processing Record 30 of Set 12 | barranca
# Processing Record 31 of Set 12 | ekhabi
# Processing Record 32 of Set 12 | charlottesville
# Processing Record 33 of Set 12 | bowen
# Processing Record 34 of Set 12 | cape coast
# Processing Record 35 of Set 12 | karpogory
# Processing Record 36 of Set 12 | husavik
# Processing Record 37 of Set 12 | maloy
# Processing Record 38 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 40 of Set 12 | nagato
# Processing Record 41 of Set 12 | waraseoni
# Processing Record 42 of Set 12 | rock sound
# Processing Record 43 of Set 12 | tomatlan
# Processing Record 44 of Set 12 | parrita
# Processing Record 45 of Set 12 | chabahar
# Processing Record 46 of Set 12 | neman
# Processing Record 47 of Set 12 | kahului
# Processing Record 48 of Set 12 | rudnya
# Processing Record 49 of Set 12 | flinders
# Processing Record 50 of Set 12 | slave lake
# Processing Record 1 of Set 13 | okha
# Processing Record 2 of Set 13 | rutland
# Processing Record 3 of Set 13 | keti bandar
# Processing Record 4 of Set 13 | ciudad bolivar
# Processing Record 5 of Set 13 | olinda
# Processing Record 6 of Set 13 | dong hoi
# Processing Record 7 of Set 13 | aykhal
# Processing Record 8 of Set 13 | altamira
# Processing Record 9 of Set 13 | buon me thuot
# City not found. Skipping...
# Processing Record 10 of Set 13 | chapada dos guimaraes
# Processing Record 11 of Set 13 | khem karan
# Processing Record 12 of Set 13 | forestville
# Processing Record 13 of Set 13 | gorom-gorom
# Processing Record 14 of Set 13 | korla
# Processing Record 15 of Set 13 | macusani
# Processing Record 16 of Set 13 | chum phae
# Processing Record 17 of Set 13 | katsuura
# Processing Record 18 of Set 13 | puerto madryn
# Processing Record 19 of Set 13 | bayan
# Processing Record 20 of Set 13 | mount isa
# Processing Record 21 of Set 13 | tiznit
# Processing Record 22 of Set 13 | ruidoso
# Processing Record 23 of Set 13 | japura
# Processing Record 24 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 25 of Set 13 | hualmay
# Processing Record 26 of Set 13 | zeya
# Processing Record 27 of Set 13 | masyaf
# Processing Record 28 of Set 13 | kropotkin
# Processing Record 29 of Set 13 | gannan
# Processing Record 30 of Set 13 | hoquiam
# Processing Record 31 of Set 13 | arkhangelsk
# Processing Record 32 of Set 13 | nyalikungu
# Processing Record 33 of Set 13 | sulangan
# Processing Record 34 of Set 13 | mataram
# Processing Record 35 of Set 13 | luwuk
# Processing Record 36 of Set 13 | presidencia roque saenz pena
# Processing Record 37 of Set 13 | college
# Processing Record 38 of Set 13 | forssa
# Processing Record 39 of Set 13 | limon
# Processing Record 40 of Set 13 | taksimo
# Processing Record 41 of Set 13 | kununurra
# Processing Record 42 of Set 13 | usinsk
# Processing Record 43 of Set 13 | ballina
# Processing Record 44 of Set 13 | high prairie
# Processing Record 45 of Set 13 | sukhoverkovo
# City not found. Skipping...
# Processing Record 46 of Set 13 | sisimiut
# Processing Record 47 of Set 13 | mincivan
# Processing Record 48 of Set 13 | viedma
# Processing Record 49 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 50 of Set 13 | barreirinhas
# Processing Record 1 of Set 14 | sorong
# Processing Record 2 of Set 14 | katherine
# Processing Record 3 of Set 14 | aasiaat
# Processing Record 4 of Set 14 | touho
# Processing Record 5 of Set 14 | montecristo
# Processing Record 6 of Set 14 | olafsvik
# Processing Record 7 of Set 14 | shenjiamen
# Processing Record 8 of Set 14 | puerto narino
# Processing Record 9 of Set 14 | buraydah
# Processing Record 10 of Set 14 | ariquemes
# Processing Record 11 of Set 14 | petatlan
# Processing Record 12 of Set 14 | salym
# Processing Record 13 of Set 14 | grafton
# Processing Record 14 of Set 14 | kitimat
# Processing Record 15 of Set 14 | horasan
# Processing Record 16 of Set 14 | shubarshi
# Processing Record 17 of Set 14 | omsukchan
# Processing Record 18 of Set 14 | aldan
# Processing Record 19 of Set 14 | yakeshi
# Processing Record 20 of Set 14 | kontagora
# Processing Record 21 of Set 14 | kousseri
# Processing Record 22 of Set 14 | orocue
# Processing Record 23 of Set 14 | vieques
# Processing Record 24 of Set 14 | amga
# Processing Record 25 of Set 14 | mana
# Processing Record 26 of Set 14 | tshela
# Processing Record 27 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 28 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 29 of Set 14 | kosovska mitrovica
# Processing Record 30 of Set 14 | cap-aux-meules
# Processing Record 31 of Set 14 | san vicente
# Processing Record 32 of Set 14 | rocha
# Processing Record 33 of Set 14 | olga
# Processing Record 34 of Set 14 | marstal
# Processing Record 35 of Set 14 | mgandu
# Processing Record 36 of Set 14 | balapur
# Processing Record 37 of Set 14 | ikovka
# Processing Record 38 of Set 14 | saint-pacome
# City not found. Skipping...
# Processing Record 39 of Set 14 | sabha
# Processing Record 40 of Set 14 | isla vista
# Processing Record 41 of Set 14 | santa rosa
# Processing Record 42 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 43 of Set 14 | bilma
# Processing Record 44 of Set 14 | broome
# Processing Record 45 of Set 14 | gat
# Processing Record 46 of Set 14 | havre-saint-pierre
# Processing Record 47 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 14 | cap malheureux
# Processing Record 49 of Set 14 | jimma
# Processing Record 50 of Set 14 | sandy bay
# Processing Record 1 of Set 15 | itoman
# Processing Record 2 of Set 15 | vilcun
# Processing Record 3 of Set 15 | rundu
# Processing Record 4 of Set 15 | prince rupert
# Processing Record 5 of Set 15 | talas
# Processing Record 6 of Set 15 | mecca
# Processing Record 7 of Set 15 | onega
# Processing Record 8 of Set 15 | flin flon
# Processing Record 9 of Set 15 | tucuma
# Processing Record 10 of Set 15 | abu kamal
# Processing Record 11 of Set 15 | tura
# Processing Record 12 of Set 15 | colares
# Processing Record 13 of Set 15 | yatou
# Processing Record 14 of Set 15 | isla mujeres
# Processing Record 15 of Set 15 | ahipara
# Processing Record 16 of Set 15 | kizilskoye
# Processing Record 17 of Set 15 | essenbach
# Processing Record 18 of Set 15 | ruwi
# Processing Record 19 of Set 15 | iracoubo
# Processing Record 20 of Set 15 | kargasok
# Processing Record 21 of Set 15 | seymchan
# Processing Record 22 of Set 15 | madera
# Processing Record 23 of Set 15 | iwaki
# Processing Record 24 of Set 15 | slantsy
# Processing Record 25 of Set 15 | pointe michel
# Processing Record 26 of Set 15 | mackenzie
# Processing Record 27 of Set 15 | haines junction
# Processing Record 28 of Set 15 | katsiveli
# City not found. Skipping...
# Processing Record 29 of Set 15 | harper
# Processing Record 30 of Set 15 | awjilah
# Processing Record 31 of Set 15 | jinhua
# Processing Record 32 of Set 15 | atchison
# Processing Record 33 of Set 15 | san jeronimo
# Processing Record 34 of Set 15 | puerto ayacucho
# Processing Record 35 of Set 15 | popondetta
# Processing Record 36 of Set 15 | muncie
# Processing Record 37 of Set 15 | campbell river
# Processing Record 38 of Set 15 | mercedes
# Processing Record 39 of Set 15 | bubaque
# Processing Record 40 of Set 15 | okahandja
# Processing Record 41 of Set 15 | fakel
# Processing Record 42 of Set 15 | karla
# Processing Record 43 of Set 15 | solnechnyy
# Processing Record 44 of Set 15 | samarai
# Processing Record 45 of Set 15 | torrijos
# Processing Record 46 of Set 15 | pangnirtung
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Karratha -20.7377  116.8463     82.00        75          92
# 1  Puerto Ayora  -0.7393  -90.3518     86.00        62          20
# 2        Exeter  50.7236   -3.5275     42.80        81          20
# 3       Ushuaia -54.8000  -68.3000     42.80        70          40
# 4     Ilulissat  69.2167  -51.1000     33.80        80          75
# 5      Qui Nhon  13.7667  109.2333     73.90        88          35
# 6        Dingle  10.9995  122.6711     73.99        87          66
# 7        Vuktyl  63.8567   57.3094     38.88        84         100
# 8    North Bend  43.4065 -124.2243     55.00        58          90
# 9    Chokurdakh  70.6333  147.9167     -4.79        88          99
#
#    Wind Speed Country Weather Description                 Date
# 0       12.21      AU          light rain  2021-04-08 21:36:41
# 1       14.97      EC          few clouds  2021-04-08 21:36:41
# 2        3.44      GB          few clouds  2021-04-08 21:36:41
# 3       32.21      AR    scattered clouds  2021-04-08 21:36:41
# 4       10.36      GL                snow  2021-04-08 21:36:41
# 5        5.61      VN    scattered clouds  2021-04-08 21:36:41
# 6        5.46      PH          light rain  2021-04-08 21:36:41
# 7       17.47      RU     overcast clouds  2021-04-08 21:36:41
# 8       12.66      US     overcast clouds  2021-04-08 21:36:41
# 9        5.41      RU     overcast clouds  2021-04-08 21:36:41

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Karratha      AU -20.7377  116.8463     82.00        75          92
# 1    Puerto Ayora      EC  -0.7393  -90.3518     86.00        62          20
# 2          Exeter      GB  50.7236   -3.5275     42.80        81          20
# 3         Ushuaia      AR -54.8000  -68.3000     42.80        70          40
# 4       Ilulissat      GL  69.2167  -51.1000     33.80        80          75
# ..            ...     ...      ...       ...       ...       ...         ...
# 671         Karla      EE  59.3723   24.9275     30.99        80           0
# 672    Solnechnyy      RU  50.7214  136.6319     25.34        82         100
# 673       Samarai      PG -10.6167  150.6667     80.38        82         100
# 674      Torrijos      ES  39.9819   -4.2835     63.00        45         100
# 675   Pangnirtung      CA  66.1451  -65.7125     24.80        86          90
#
#      Wind Speed Weather Description
# 0         12.21          light rain
# 1         14.97          few clouds
# 2          3.44          few clouds
# 3         32.21    scattered clouds
# 4         10.36                snow
# ..          ...                 ...
# 671        6.91           clear sky
# 672        7.94     overcast clouds
# 673       11.70     overcast clouds
# 674        5.39     overcast clouds
# 675       14.97                snow
#
# [676 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
